# %% [markdown]
# **References used for the dataset**
# 1. https://www.cs.toronto.edu/~kriz/cifar.html
# 2. https://keras.io/api/datasets/cifar100/
#
# **References used for the network architecture**
# 1. https://arxiv.org/abs/1704.06904
# 2. https://github.com/tengshaofeng/ResidualAttentionNetwork-pytorch/blob/master/Residual-Attention-Network/model/attention_module.py
# 3. https://github.com/Piyushdharkar/Residual-Attention-Aware-Network
# 4. https://github.com/deontaepharr/Residual-Attention-Network
#
# **References used for keras functions**
# 1. https://www.pyimagesearch.com/2019/07/22/keras-learning-rate-schedules-and-decay/
# 2. https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
# https://www.pyimagesearch.com/2019/07/08/keras-imagedatagenerator-and-data-augmentation/

# %%
import numpy as np
import time
import tensorflow as tf
from matplotlib import pyplot as plt

# %% [markdown]
# **Load the CIFAR-100 Dataset**

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar100.load_data()

# %%
print("\n x_train.shape: ", x_train.shape)
print("\n y_train.shape: ", y_train.shape)

print("\n x_test.shape: ", x_test.shape)
print("\n y_test.shape: ", y_test.shape)
# Out:
#  x_train.shape:  (50000, 32, 32, 3)
#
#  y_train.shape:  (50000, 1)
#
#  x_test.shape:  (10000, 32, 32, 3)
#
#  y_test.shape:  (10000, 1)

# %% [markdown]
# **Visualize the dataset**

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize=(10, 10))

axes[0, 0].imshow(x_train[10])
axes[0, 1].imshow(x_train[200])
axes[1, 0].imshow(x_train[0])
axes[1, 1].imshow(x_train[500])

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes = 100)
y_test = tf.keras.utils.to_categorical(y_test, num_classes = 100)

# %% [markdown]
# **Divide the data into train, test and validation**

# %%
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, train_size = 0.8)

print("\n x_train.shape: ", x_train.shape)
print("\n y_train.shape: ", y_train.shape)

print("\n x_val.shape: ", x_val.shape)
print("\n y_val.shape: ", y_val.shape)

print("\n x_test.shape: ", x_test.shape)
print("\n y_test.shape: ", y_test.shape)
# Out:
#  x_train.shape:  (40000, 32, 32, 3)
#
#  y_train.shape:  (40000, 100)
#
#  x_val.shape:  (10000, 32, 32, 3)
#
#  y_val.shape:  (10000, 100)
#
#  x_test.shape:  (10000, 32, 32, 3)
#
#  y_test.shape:  (10000, 100)

# %% [markdown]
# **Creating Residual Block**

# %%
from tensorflow.keras import activations

# %%
def create_residual_block(val_in, filter_in, filter_out):
    '''
    @params val_in : Input shape
    @params filter_in : Input filter
    @params filter_out : Output filter
    @output : Tensor created after residual block
    '''
    
    # Repeat BN=>ReLU=>Conv2D pattern three times
    
    x = tf.keras.layers.BatchNormalization()(val_in)
    x = tf.keras.activations.relu(x)
    x = tf.keras.layers.Conv2D(filters = filter_in, kernel_size = 1, padding = 'same')(x)
    
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = tf.keras.layers.Conv2D(filters = filter_out, kernel_size = 3, padding = 'same')(x)
    
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.activations.relu(x)
    x = tf.keras.layers.Conv2D(filters = filter_out, kernel_size = 1, padding = 'same')(x)
    
    val_in = tf.keras.layers.Conv2D(filters = filter_out, kernel_size = 1, padding = 'same')(val_in)
    
    x = tf.keras.layers.Add()([val_in, x])
    
    return x

# %% [markdown]
# **Creating Attention Block**
#
# The attention Module consists of mask branch and trunk branch. The trunk branch performs feature selection (using the residual blocks) and the mask branch learns the mask to be applied from downsampling and upsampling. The output of the attention block is (1+M(x)).T(x), where M(x) is the mask and T(x) is the output of the trunk branch (pre-processing).

# %%
def create_attention_block(val_in, filter_in, filter_out, p = 1, t = 2, r = 1):
    '''
    @params val_in : Input shape
    @params filter_in : Input filter
    @params filter_out : Output filter
    @params p : Number of pre-processing residual units before splitting into trunk and mask branch (is also a hyperparameter)
    @params t : Number of residual units in trunk branch (is also a hyperparameter)
    @params r : Number of residual units between adjacent pooling layer in the mask branch (is also a hyperparameter)
    @output: Tensor created after attention block
    '''
    
    # Creating residual blocks for pre-processing residual units
    for units in range(p):
        val_in = create_residual_block(val_in, filter_in, filter_out)
     
    val_out_trunk = val_in
    
    # Feature Processing for the trunk branch. Input to the trunk branch is the output of the pre-processing residual blocks
    for units in range(t):
        val_out_trunk = create_residual_block(val_out_trunk, filter_in, filter_out)
        
    # 1. Downsample using MaxPool2D
    # 2. 'r' represents the number of residual units between two max pool layers in the mask branch. Implemented using for loop
    # 3. Add skip connection
    # 4. Upsample using UpSampling2D
    
    
    # Down Sampling One
    soft_mask_output = tf.keras.layers.MaxPool2D(pool_size = 2, padding = 'same')(val_in)
    for units in range(r):
        soft_mask_output = create_residual_block(soft_mask_output, filter_in, filter_out)
    
    
    # Adding Skip Connection
    skip_connection = create_residual_block(soft_mask_output, filter_in, filter_out)
    
    # Down Sampling Two
    soft_mask_output = tf.keras.layers.MaxPool2D(pool_size = 2, padding = 'same')(soft_mask_output)
    for units in range(r):
        soft_mask_output = create_residual_block(soft_mask_output, filter_in, filter_out)
    
    # Up Sampling One
    for units in range(r):
        soft_mask_output = create_residual_block(soft_mask_output, filter_in, filter_out)
        soft_mask_output = tf.keras.layers.UpSampling2D(size=2)(soft_mask_output)
        soft_mask_output = tf.keras.layers.Add()([soft_mask_output, skip_connection])
        
    # Up Sampling Two
    for units in range(r):
        soft_mask_output = create_residual_block(soft_mask_output, filter_in, filter_out)
    soft_mask_output = tf.keras.layers.UpSampling2D(size=2)(soft_mask_output)
    
    soft_mask_output = tf.keras.layers.Conv2D(filter_in, kernel_size=1)(soft_mask_output)
    soft_mask_output = tf.keras.layers.Conv2D(filter_in, kernel_size=1)(soft_mask_output)
    soft_mask_output = tf.keras.layers.Activation(activation='sigmoid')(soft_mask_output)
    
    # Output is (1 + M(x))*T(x)
    output = tf.keras.layers.Lambda(lambda x: x + 1)(soft_mask_output)
    output = tf.keras.layers.Multiply()([output, val_out_trunk]) 
    
    for i in range(p):
        output = create_residual_block(output, filter_in, filter_out)

    return output

# %% [markdown]
# **Creating the Model**

# %%
def create_model(size, classes):
    '''
    @params size : Input tensor siz
    @params classes : Number of output classes
    @output : Returns the model created by attention modules
    '''
    val_in = tf.keras.layers.Input(shape=size)
    x = tf.keras.layers.Conv2D(filters=32, kernel_size=5, strides=1, padding='same')(val_in)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation(activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=2, strides=1, padding='same')(x)

    x = create_residual_block(val_in=x, filter_in=32, filter_out=128)
    x = create_attention_block(val_in=x, filter_in=32, filter_out=32)
    x = tf.keras.layers.Dropout(0.25)(x)

    x = create_residual_block(val_in=x, filter_in=64, filter_out=128)
    x = create_attention_block(val_in=x, filter_in=64, filter_out=64)
    x = tf.keras.layers.Dropout(0.25)(x)

    x = create_residual_block(val_in=x, filter_in=128, filter_out=256)
    x = create_attention_block(val_in=x, filter_in=128, filter_out=128)
    x = tf.keras.layers.Dropout(0.25)(x)

    x = create_residual_block(val_in=x, filter_in=128, filter_out=256)
    x = create_residual_block(val_in=x, filter_in=256, filter_out=256)
    x = create_residual_block(val_in=x, filter_in=256, filter_out=256)

    x = tf.keras.layers.AveragePooling2D(pool_size=4)(x)
    x = tf.keras.layers.Flatten()(x)

    output = tf.keras.layers.Dense(classes, activation='softmax')(x)


    return tf.keras.models.Model(val_in, output)

# %% [markdown]
# **Initialize the Model**

# %%
model_cifar_100 = create_model(x_train.shape[1:], 100)

model_cifar_100.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Viusalize the Model**
#
# To visualize the model, we use the Netron Package
#
# 1. Install netron using the pip command below
#
# 2. Download Netron package from here : https://github.com/lutzroeder/netron/releases/tag/v5.4.3
#
# 3. Save the model using the command below
#
# 4. Open and visualize the saved model with Netron

# %%
pip install netron
# Out:
# Requirement already satisfied: netron in /opt/conda/lib/python3.7/site-packages (5.4.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
model_cifar_100.save('model_cifar_100.h5')

# %% [markdown]
# **Train the Model**

# %%
def lr_schedule (epoch, lr):
    if epoch == 100:
        lr = 0.1 * lr
        print("\n Reducing learning by factor of 10 at epoch: ", epoch)
    elif epoch == 150:
        lr = 0.1 * lr
        print("\n Reducing learning by factor of 10 at epoch: ", epoch)
    
    return lr

# %%
augmented_data_train = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.2, vertical_flip=True, 
                                                           rotation_range=0.15, width_shift_range=0.15, height_shift_range=0.15,
                                                           zoom_range=0.15)

augmented_data_val = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

flow_data_train = augmented_data_train.flow(x_train, y_train)

flow_data_val = augmented_data_val.flow(x_val, y_val)

# %%
tic = time.time()

callback = tf.keras.callbacks.LearningRateScheduler(lr_schedule)

history_cifar_100 = model_cifar_100.fit(flow_data_train, validation_data=flow_data_val, batch_size=64, 
                                        steps_per_epoch=flow_data_train.n // 64, validation_steps=flow_data_val.n // 64, epochs = 256,
                                       callbacks=[callback])

toc = time.time()
# Out:
# Epoch 1/256
# 625/625 [==============================] - 82s 116ms/step - loss: 5.5174 - accuracy: 0.0559 - val_loss: 5.8702 - val_accuracy: 0.0507 - lr: 0.0010
# Epoch 2/256
# 625/625 [==============================] - 71s 114ms/step - loss: 4.0432 - accuracy: 0.1006 - val_loss: 4.5819 - val_accuracy: 0.0825 - lr: 0.0010
# Epoch 3/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.8101 - accuracy: 0.1229 - val_loss: 4.1506 - val_accuracy: 0.1222 - lr: 0.0010
# Epoch 4/256
# 625/625 [==============================] - 73s 117ms/step - loss: 3.7169 - accuracy: 0.1363 - val_loss: 4.5849 - val_accuracy: 0.0909 - lr: 0.0010
# Epoch 5/256
# 625/625 [==============================] - 73s 117ms/step - loss: 3.6692 - accuracy: 0.1463 - val_loss: 3.9563 - val_accuracy: 0.1150 - lr: 0.0010
# Epoch 6/256
# 625/625 [==============================] - 73s 117ms/step - loss: 3.5956 - accuracy: 0.1552 - val_loss: 3.5977 - val_accuracy: 0.1488 - lr: 0.0010
# Epoch 7/256
# 625/625 [==============================] - 74s 118ms/step - loss: 3.5662 - accuracy: 0.1601 - val_loss: 4.2103 - val_accuracy: 0.1026 - lr: 0.0010
# Epoch 8/256
# 625/625 [==============================] - 73s 116ms/step - loss: 3.5326 - accuracy: 0.1679 - val_loss: 3.3845 - val_accuracy: 0.1829 - lr: 0.0010
# Epoch 9/256
# 625/625 [==============================] - 78s 124ms/step - loss: 3.4980 - accuracy: 0.1692 - val_loss: 3.6802 - val_accuracy: 0.1617 - lr: 0.0010
# Epoch 10/256
# 625/625 [==============================] - 79s 126ms/step - loss: 3.4736 - accuracy: 0.1717 - val_loss: 3.7492 - val_accuracy: 0.1484 - lr: 0.0010
# Epoch 11/256
# 625/625 [==============================] - 73s 117ms/step - loss: 3.3703 - accuracy: 0.1905 - val_loss: 3.4910 - val_accuracy: 0.1751 - lr: 0.0010
# Epoch 12/256
# 625/625 [==============================] - 72s 114ms/step - loss: 3.3179 - accuracy: 0.1974 - val_loss: 3.3360 - val_accuracy: 0.2055 - lr: 0.0010
# Epoch 13/256
# 625/625 [==============================] - 71s 114ms/step - loss: 3.2848 - accuracy: 0.2112 - val_loss: 3.7340 - val_accuracy: 0.1518 - lr: 0.0010
# Epoch 14/256
# 625/625 [==============================] - 71s 114ms/step - loss: 3.2237 - accuracy: 0.2177 - val_loss: 3.6469 - val_accuracy: 0.1619 - lr: 0.0010
# Epoch 15/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.2781 - accuracy: 0.2101 - val_loss: 3.3948 - val_accuracy: 0.2049 - lr: 0.0010
# Epoch 16/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.1780 - accuracy: 0.2249 - val_loss: 3.5454 - val_accuracy: 0.2069 - lr: 0.0010
# Epoch 17/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.1274 - accuracy: 0.2335 - val_loss: 3.1876 - val_accuracy: 0.2324 - lr: 0.0010
# Epoch 18/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.0841 - accuracy: 0.2442 - val_loss: 3.1509 - val_accuracy: 0.2450 - lr: 0.0010
# Epoch 19/256
# 625/625 [==============================] - 70s 113ms/step - loss: 3.0293 - accuracy: 0.2517 - val_loss: 4.3340 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 20/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.0181 - accuracy: 0.2539 - val_loss: 3.0988 - val_accuracy: 0.2566 - lr: 0.0010
# Epoch 21/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.0107 - accuracy: 0.2545 - val_loss: 3.0409 - val_accuracy: 0.2516 - lr: 0.0010
# Epoch 22/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.9457 - accuracy: 0.2702 - val_loss: 4.1204 - val_accuracy: 0.1562 - lr: 0.0010
# Epoch 23/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.9131 - accuracy: 0.2738 - val_loss: 4.0194 - val_accuracy: 0.1649 - lr: 0.0010
# Epoch 24/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.8970 - accuracy: 0.2803 - val_loss: 3.5203 - val_accuracy: 0.1985 - lr: 0.0010
# Epoch 25/256
# 625/625 [==============================] - 76s 121ms/step - loss: 2.8657 - accuracy: 0.2833 - val_loss: 3.0618 - val_accuracy: 0.2656 - lr: 0.0010
# Epoch 26/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.8406 - accuracy: 0.2892 - val_loss: 3.4939 - val_accuracy: 0.2157 - lr: 0.0010
# Epoch 27/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.8012 - accuracy: 0.2918 - val_loss: 3.4644 - val_accuracy: 0.2119 - lr: 0.0010
# Epoch 28/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.7895 - accuracy: 0.2995 - val_loss: 3.8491 - val_accuracy: 0.2017 - lr: 0.0010
# Epoch 29/256
# 625/625 [==============================] - 72s 116ms/step - loss: 8.6891 - accuracy: 0.1968 - val_loss: 4.5462 - val_accuracy: 0.0405 - lr: 0.0010
# Epoch 30/256
# 625/625 [==============================] - 71s 114ms/step - loss: 3.7624 - accuracy: 0.1376 - val_loss: 3.2982 - val_accuracy: 0.2240 - lr: 0.0010
# Epoch 31/256
# 625/625 [==============================] - 71s 113ms/step - loss: 3.1127 - accuracy: 0.2403 - val_loss: 2.8919 - val_accuracy: 0.2815 - lr: 0.0010
# Epoch 32/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.9144 - accuracy: 0.2797 - val_loss: 2.8158 - val_accuracy: 0.3073 - lr: 0.0010
# Epoch 33/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.8464 - accuracy: 0.2934 - val_loss: 2.7606 - val_accuracy: 0.3213 - lr: 0.0010
# Epoch 34/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.7390 - accuracy: 0.3133 - val_loss: 3.0391 - val_accuracy: 0.2935 - lr: 0.0010
# Epoch 35/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.7251 - accuracy: 0.3143 - val_loss: 2.8333 - val_accuracy: 0.3047 - lr: 0.0010
# Epoch 36/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.6773 - accuracy: 0.3257 - val_loss: 2.6144 - val_accuracy: 0.3512 - lr: 0.0010
# Epoch 37/256
# 625/625 [==============================] - 70s 112ms/step - loss: 2.6601 - accuracy: 0.3290 - val_loss: 2.7556 - val_accuracy: 0.3217 - lr: 0.0010
# Epoch 38/256
# 625/625 [==============================] - 70s 112ms/step - loss: 2.6295 - accuracy: 0.3322 - val_loss: 2.8091 - val_accuracy: 0.3115 - lr: 0.0010
# Epoch 39/256
# 625/625 [==============================] - 70s 112ms/step - loss: 2.6194 - accuracy: 0.3394 - val_loss: 2.8548 - val_accuracy: 0.3211 - lr: 0.0010
# Epoch 40/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.6026 - accuracy: 0.3392 - val_loss: 3.0088 - val_accuracy: 0.3003 - lr: 0.0010
# Epoch 41/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.6113 - accuracy: 0.3364 - val_loss: 3.2124 - val_accuracy: 0.2616 - lr: 0.0010
# Epoch 42/256
# 625/625 [==============================] - 70s 112ms/step - loss: 2.5736 - accuracy: 0.3443 - val_loss: 3.4862 - val_accuracy: 0.2514 - lr: 0.0010
# Epoch 43/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.5398 - accuracy: 0.3555 - val_loss: 3.6913 - val_accuracy: 0.2362 - lr: 0.0010
# Epoch 44/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.5617 - accuracy: 0.3433 - val_loss: 3.9290 - val_accuracy: 0.2234 - lr: 0.0010
# Epoch 45/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.5423 - accuracy: 0.3478 - val_loss: 3.1501 - val_accuracy: 0.2774 - lr: 0.0010
# Epoch 46/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.5975 - accuracy: 0.3458 - val_loss: 5.8266 - val_accuracy: 0.0938 - lr: 0.0010
# Epoch 47/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.5830 - accuracy: 0.3452 - val_loss: 3.8298 - val_accuracy: 0.2248 - lr: 0.0010
# Epoch 48/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.4754 - accuracy: 0.3678 - val_loss: 3.7383 - val_accuracy: 0.2378 - lr: 0.0010
# Epoch 49/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.4651 - accuracy: 0.3710 - val_loss: 2.9206 - val_accuracy: 0.3105 - lr: 0.0010
# Epoch 50/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.4473 - accuracy: 0.3722 - val_loss: 3.1947 - val_accuracy: 0.2766 - lr: 0.0010
# Epoch 51/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.4409 - accuracy: 0.3734 - val_loss: 2.8212 - val_accuracy: 0.3219 - lr: 0.0010
# Epoch 52/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.4194 - accuracy: 0.3800 - val_loss: 2.9268 - val_accuracy: 0.3013 - lr: 0.0010
# Epoch 53/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.4169 - accuracy: 0.3810 - val_loss: 3.0087 - val_accuracy: 0.3007 - lr: 0.0010
# Epoch 54/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.3973 - accuracy: 0.3860 - val_loss: 2.9423 - val_accuracy: 0.3081 - lr: 0.0010
# Epoch 55/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.3869 - accuracy: 0.3882 - val_loss: 2.8640 - val_accuracy: 0.3199 - lr: 0.0010
# Epoch 56/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.3549 - accuracy: 0.3949 - val_loss: 3.6168 - val_accuracy: 0.2462 - lr: 0.0010
# Epoch 57/256
# 625/625 [==============================] - 70s 113ms/step - loss: 8.0494 - accuracy: 0.1552 - val_loss: 3.6919 - val_accuracy: 0.2053 - lr: 0.0010
# Epoch 58/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.7036 - accuracy: 0.3190 - val_loss: 2.5579 - val_accuracy: 0.3692 - lr: 0.0010
# Epoch 59/256
# 625/625 [==============================] - 70s 112ms/step - loss: 2.4688 - accuracy: 0.3665 - val_loss: 2.7169 - val_accuracy: 0.3510 - lr: 0.0010
# Epoch 60/256
# 625/625 [==============================] - 70s 112ms/step - loss: 2.3870 - accuracy: 0.3885 - val_loss: 2.4556 - val_accuracy: 0.3838 - lr: 0.0010
# Epoch 61/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.3503 - accuracy: 0.3927 - val_loss: 2.4329 - val_accuracy: 0.3924 - lr: 0.0010
# Epoch 62/256
# 625/625 [==============================] - 70s 112ms/step - loss: 2.3384 - accuracy: 0.3970 - val_loss: 2.6985 - val_accuracy: 0.3458 - lr: 0.0010
# Epoch 63/256
# 625/625 [==============================] - 76s 122ms/step - loss: 2.3035 - accuracy: 0.4051 - val_loss: 2.5839 - val_accuracy: 0.3696 - lr: 0.0010
# Epoch 64/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.2947 - accuracy: 0.4057 - val_loss: 2.6720 - val_accuracy: 0.3536 - lr: 0.0010
# Epoch 65/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.2671 - accuracy: 0.4040 - val_loss: 2.6202 - val_accuracy: 0.3728 - lr: 0.0010
# Epoch 66/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.2890 - accuracy: 0.4076 - val_loss: 3.2477 - val_accuracy: 0.2815 - lr: 0.0010
# Epoch 67/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.2943 - accuracy: 0.4102 - val_loss: 2.6346 - val_accuracy: 0.3658 - lr: 0.0010
# Epoch 68/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.2603 - accuracy: 0.4119 - val_loss: 2.7453 - val_accuracy: 0.3452 - lr: 0.0010
# Epoch 69/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.2453 - accuracy: 0.4144 - val_loss: 3.0322 - val_accuracy: 0.3073 - lr: 0.0010
# Epoch 70/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.2474 - accuracy: 0.4195 - val_loss: 3.2617 - val_accuracy: 0.2831 - lr: 0.0010
# Epoch 71/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.2689 - accuracy: 0.4124 - val_loss: 3.4174 - val_accuracy: 0.2871 - lr: 0.0010
# Epoch 72/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.2338 - accuracy: 0.4159 - val_loss: 2.6744 - val_accuracy: 0.3558 - lr: 0.0010
# Epoch 73/256
# 625/625 [==============================] - 70s 113ms/step - loss: 2.2302 - accuracy: 0.4157 - val_loss: 2.6560 - val_accuracy: 0.3606 - lr: 0.0010
# Epoch 74/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.2257 - accuracy: 0.4171 - val_loss: 5.9525 - val_accuracy: 0.1468 - lr: 0.0010
# Epoch 75/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.1922 - accuracy: 0.4268 - val_loss: 3.4511 - val_accuracy: 0.2546 - lr: 0.0010
# Epoch 76/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.2023 - accuracy: 0.4261 - val_loss: 3.4116 - val_accuracy: 0.2602 - lr: 0.0010
# Epoch 77/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.1970 - accuracy: 0.4267 - val_loss: 3.3025 - val_accuracy: 0.2951 - lr: 0.0010
# Epoch 78/256
# 625/625 [==============================] - 71s 113ms/step - loss: 2.1782 - accuracy: 0.4261 - val_loss: 3.1988 - val_accuracy: 0.3099 - lr: 0.0010
# Epoch 79/256
# 625/625 [==============================] - 77s 123ms/step - loss: 2.1666 - accuracy: 0.4383 - val_loss: 2.5494 - val_accuracy: 0.3832 - lr: 0.0010
# Epoch 80/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1490 - accuracy: 0.4386 - val_loss: 2.8017 - val_accuracy: 0.3331 - lr: 0.0010
# Epoch 81/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1643 - accuracy: 0.4381 - val_loss: 3.0575 - val_accuracy: 0.3351 - lr: 0.0010
# Epoch 82/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1383 - accuracy: 0.4424 - val_loss: 2.8030 - val_accuracy: 0.3363 - lr: 0.0010
# Epoch 83/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1503 - accuracy: 0.4369 - val_loss: 3.5156 - val_accuracy: 0.2646 - lr: 0.0010
# Epoch 84/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1262 - accuracy: 0.4401 - val_loss: 2.6032 - val_accuracy: 0.3578 - lr: 0.0010
# Epoch 85/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1170 - accuracy: 0.4408 - val_loss: 2.8895 - val_accuracy: 0.3506 - lr: 0.0010
# Epoch 86/256
# 625/625 [==============================] - 72s 115ms/step - loss: 2.1157 - accuracy: 0.4468 - val_loss: 2.7630 - val_accuracy: 0.3678 - lr: 0.0010
# Epoch 87/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1006 - accuracy: 0.4490 - val_loss: 3.2224 - val_accuracy: 0.3117 - lr: 0.0010
# Epoch 88/256
# 625/625 [==============================] - 72s 115ms/step - loss: 2.0932 - accuracy: 0.4454 - val_loss: 2.6890 - val_accuracy: 0.3662 - lr: 0.0010
# Epoch 89/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.0970 - accuracy: 0.4520 - val_loss: 2.1965 - val_accuracy: 0.4335 - lr: 0.0010
# Epoch 90/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.0701 - accuracy: 0.4521 - val_loss: 2.7728 - val_accuracy: 0.3626 - lr: 0.0010
# Epoch 91/256
# 625/625 [==============================] - 72s 114ms/step - loss: 2.0551 - accuracy: 0.4577 - val_loss: 2.8594 - val_accuracy: 0.3706 - lr: 0.0010
# Epoch 92/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.0455 - accuracy: 0.4591 - val_loss: 5.4225 - val_accuracy: 0.1589 - lr: 0.0010
# Epoch 93/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.0561 - accuracy: 0.4589 - val_loss: 3.1387 - val_accuracy: 0.3007 - lr: 0.0010
# Epoch 94/256
# 625/625 [==============================] - 72s 115ms/step - loss: 2.0980 - accuracy: 0.4464 - val_loss: 3.2841 - val_accuracy: 0.3121 - lr: 0.0010
# Epoch 95/256
# 625/625 [==============================] - 71s 114ms/step - loss: 9.2316 - accuracy: 0.1403 - val_loss: 4.2250 - val_accuracy: 0.0887 - lr: 0.0010
# Epoch 96/256
# 625/625 [==============================] - 77s 124ms/step - loss: 3.2524 - accuracy: 0.2244 - val_loss: 2.7576 - val_accuracy: 0.3357 - lr: 0.0010
# Epoch 97/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.5271 - accuracy: 0.3561 - val_loss: 2.8095 - val_accuracy: 0.3417 - lr: 0.0010
# Epoch 98/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.3016 - accuracy: 0.4045 - val_loss: 2.6154 - val_accuracy: 0.3936 - lr: 0.0010
# Epoch 99/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.2036 - accuracy: 0.4272 - val_loss: 2.5196 - val_accuracy: 0.3908 - lr: 0.0010
# Epoch 100/256
# 625/625 [==============================] - 71s 114ms/step - loss: 2.1273 - accuracy: 0.4448 - val_loss: 2.6368 - val_accuracy: 0.3828 - lr: 0.0010
#
#  Reducing learning by factor of 10 at epoch:  100
# Epoch 101/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.8941 - accuracy: 0.4976 - val_loss: 2.3155 - val_accuracy: 0.4295 - lr: 1.0000e-04
# Epoch 102/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.8987 - accuracy: 0.4929 - val_loss: 2.4151 - val_accuracy: 0.4243 - lr: 1.0000e-04
# Epoch 103/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.8624 - accuracy: 0.5056 - val_loss: 2.2606 - val_accuracy: 0.4425 - lr: 1.0000e-04
# Epoch 104/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.8565 - accuracy: 0.5087 - val_loss: 2.3038 - val_accuracy: 0.4327 - lr: 1.0000e-04
# Epoch 105/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.8550 - accuracy: 0.5039 - val_loss: 2.2209 - val_accuracy: 0.4587 - lr: 1.0000e-04
# Epoch 106/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.8147 - accuracy: 0.5132 - val_loss: 2.2483 - val_accuracy: 0.4479 - lr: 1.0000e-04
# Epoch 107/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.8463 - accuracy: 0.5074 - val_loss: 2.2759 - val_accuracy: 0.4457 - lr: 1.0000e-04
# Epoch 108/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.8070 - accuracy: 0.5165 - val_loss: 2.2122 - val_accuracy: 0.4603 - lr: 1.0000e-04
# Epoch 109/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.8051 - accuracy: 0.5156 - val_loss: 2.2005 - val_accuracy: 0.4573 - lr: 1.0000e-04
# Epoch 110/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.7837 - accuracy: 0.5261 - val_loss: 2.3827 - val_accuracy: 0.4393 - lr: 1.0000e-04
# Epoch 111/256
# 625/625 [==============================] - 72s 114ms/step - loss: 1.7748 - accuracy: 0.5258 - val_loss: 2.1697 - val_accuracy: 0.4613 - lr: 1.0000e-04
# Epoch 112/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7715 - accuracy: 0.5283 - val_loss: 2.3700 - val_accuracy: 0.4311 - lr: 1.0000e-04
# Epoch 113/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7564 - accuracy: 0.5260 - val_loss: 2.1870 - val_accuracy: 0.4541 - lr: 1.0000e-04
# Epoch 114/256
# 625/625 [==============================] - 77s 123ms/step - loss: 1.7497 - accuracy: 0.5308 - val_loss: 2.4233 - val_accuracy: 0.4201 - lr: 1.0000e-04
# Epoch 115/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7453 - accuracy: 0.5347 - val_loss: 2.2176 - val_accuracy: 0.4623 - lr: 1.0000e-04
# Epoch 116/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7431 - accuracy: 0.5307 - val_loss: 2.2646 - val_accuracy: 0.4469 - lr: 1.0000e-04
# Epoch 117/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7367 - accuracy: 0.5363 - val_loss: 2.2182 - val_accuracy: 0.4599 - lr: 1.0000e-04
# Epoch 118/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7107 - accuracy: 0.5383 - val_loss: 2.1582 - val_accuracy: 0.4722 - lr: 1.0000e-04
# Epoch 119/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7070 - accuracy: 0.5436 - val_loss: 2.1242 - val_accuracy: 0.4673 - lr: 1.0000e-04
# Epoch 120/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7147 - accuracy: 0.5407 - val_loss: 2.2768 - val_accuracy: 0.4481 - lr: 1.0000e-04
# Epoch 121/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.7289 - accuracy: 0.5355 - val_loss: 2.2343 - val_accuracy: 0.4557 - lr: 1.0000e-04
# Epoch 122/256
# 625/625 [==============================] - 76s 122ms/step - loss: 1.7150 - accuracy: 0.5372 - val_loss: 2.2876 - val_accuracy: 0.4271 - lr: 1.0000e-04
# Epoch 123/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6762 - accuracy: 0.5444 - val_loss: 2.2736 - val_accuracy: 0.4549 - lr: 1.0000e-04
# Epoch 124/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6825 - accuracy: 0.5447 - val_loss: 2.2650 - val_accuracy: 0.4481 - lr: 1.0000e-04
# Epoch 125/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6785 - accuracy: 0.5433 - val_loss: 2.3252 - val_accuracy: 0.4423 - lr: 1.0000e-04
# Epoch 126/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6762 - accuracy: 0.5459 - val_loss: 2.2612 - val_accuracy: 0.4549 - lr: 1.0000e-04
# Epoch 127/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6681 - accuracy: 0.5472 - val_loss: 2.2444 - val_accuracy: 0.4549 - lr: 1.0000e-04
# Epoch 128/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6685 - accuracy: 0.5483 - val_loss: 2.3483 - val_accuracy: 0.4405 - lr: 1.0000e-04
# Epoch 129/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6552 - accuracy: 0.5523 - val_loss: 2.2562 - val_accuracy: 0.4489 - lr: 1.0000e-04
# Epoch 130/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6359 - accuracy: 0.5570 - val_loss: 2.1832 - val_accuracy: 0.4692 - lr: 1.0000e-04
# Epoch 131/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6603 - accuracy: 0.5515 - val_loss: 2.1078 - val_accuracy: 0.4792 - lr: 1.0000e-04
# Epoch 132/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6332 - accuracy: 0.5553 - val_loss: 2.1659 - val_accuracy: 0.4694 - lr: 1.0000e-04
# Epoch 133/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6456 - accuracy: 0.5533 - val_loss: 2.2034 - val_accuracy: 0.4615 - lr: 1.0000e-04
# Epoch 134/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6288 - accuracy: 0.5587 - val_loss: 2.3552 - val_accuracy: 0.4385 - lr: 1.0000e-04
# Epoch 135/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6389 - accuracy: 0.5569 - val_loss: 2.2680 - val_accuracy: 0.4517 - lr: 1.0000e-04
# Epoch 136/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6318 - accuracy: 0.5553 - val_loss: 2.1688 - val_accuracy: 0.4631 - lr: 1.0000e-04
# Epoch 137/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6353 - accuracy: 0.5598 - val_loss: 2.0872 - val_accuracy: 0.4830 - lr: 1.0000e-04
# Epoch 138/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6123 - accuracy: 0.5612 - val_loss: 2.2306 - val_accuracy: 0.4627 - lr: 1.0000e-04
# Epoch 139/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6205 - accuracy: 0.5621 - val_loss: 2.2545 - val_accuracy: 0.4587 - lr: 1.0000e-04
# Epoch 140/256
# 625/625 [==============================] - 76s 122ms/step - loss: 1.6156 - accuracy: 0.5604 - val_loss: 2.2224 - val_accuracy: 0.4627 - lr: 1.0000e-04
# Epoch 141/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6015 - accuracy: 0.5656 - val_loss: 2.2139 - val_accuracy: 0.4655 - lr: 1.0000e-04
# Epoch 142/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6023 - accuracy: 0.5633 - val_loss: 2.2136 - val_accuracy: 0.4679 - lr: 1.0000e-04
# Epoch 143/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5875 - accuracy: 0.5683 - val_loss: 2.1551 - val_accuracy: 0.4663 - lr: 1.0000e-04
# Epoch 144/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5811 - accuracy: 0.5702 - val_loss: 2.2811 - val_accuracy: 0.4575 - lr: 1.0000e-04
# Epoch 145/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5807 - accuracy: 0.5671 - val_loss: 2.1880 - val_accuracy: 0.4685 - lr: 1.0000e-04
# Epoch 146/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5817 - accuracy: 0.5690 - val_loss: 2.1442 - val_accuracy: 0.4770 - lr: 1.0000e-04
# Epoch 147/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5874 - accuracy: 0.5689 - val_loss: 2.1463 - val_accuracy: 0.4671 - lr: 1.0000e-04
# Epoch 148/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5853 - accuracy: 0.5699 - val_loss: 2.1555 - val_accuracy: 0.4762 - lr: 1.0000e-04
# Epoch 149/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.6001 - accuracy: 0.5634 - val_loss: 2.0936 - val_accuracy: 0.4872 - lr: 1.0000e-04
# Epoch 150/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5657 - accuracy: 0.5717 - val_loss: 2.1489 - val_accuracy: 0.4830 - lr: 1.0000e-04
#
#  Reducing learning by factor of 10 at epoch:  150
# Epoch 151/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5389 - accuracy: 0.5803 - val_loss: 2.1041 - val_accuracy: 0.4744 - lr: 1.0000e-05
# Epoch 152/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5198 - accuracy: 0.5817 - val_loss: 2.0871 - val_accuracy: 0.4846 - lr: 1.0000e-05
# Epoch 153/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5520 - accuracy: 0.5756 - val_loss: 2.1525 - val_accuracy: 0.4756 - lr: 1.0000e-05
# Epoch 154/256
# 625/625 [==============================] - 76s 122ms/step - loss: 1.5234 - accuracy: 0.5825 - val_loss: 2.1649 - val_accuracy: 0.4802 - lr: 1.0000e-05
# Epoch 155/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5432 - accuracy: 0.5791 - val_loss: 2.1415 - val_accuracy: 0.4818 - lr: 1.0000e-05
# Epoch 156/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5346 - accuracy: 0.5768 - val_loss: 2.1501 - val_accuracy: 0.4816 - lr: 1.0000e-05
# Epoch 157/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5137 - accuracy: 0.5840 - val_loss: 2.0845 - val_accuracy: 0.4882 - lr: 1.0000e-05
# Epoch 158/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5307 - accuracy: 0.5819 - val_loss: 2.1045 - val_accuracy: 0.4778 - lr: 1.0000e-05
# Epoch 159/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5419 - accuracy: 0.5789 - val_loss: 2.0841 - val_accuracy: 0.4842 - lr: 1.0000e-05
# Epoch 160/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5251 - accuracy: 0.5810 - val_loss: 2.1121 - val_accuracy: 0.4850 - lr: 1.0000e-05
# Epoch 161/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5244 - accuracy: 0.5814 - val_loss: 2.1209 - val_accuracy: 0.4832 - lr: 1.0000e-05
# Epoch 162/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5286 - accuracy: 0.5824 - val_loss: 2.1424 - val_accuracy: 0.4702 - lr: 1.0000e-05
# Epoch 163/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5300 - accuracy: 0.5834 - val_loss: 2.1272 - val_accuracy: 0.4808 - lr: 1.0000e-05
# Epoch 164/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5113 - accuracy: 0.5896 - val_loss: 2.1063 - val_accuracy: 0.4772 - lr: 1.0000e-05
# Epoch 165/256
# 625/625 [==============================] - 70s 113ms/step - loss: 1.5348 - accuracy: 0.5839 - val_loss: 2.1107 - val_accuracy: 0.4812 - lr: 1.0000e-05
# Epoch 166/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5312 - accuracy: 0.5831 - val_loss: 2.1430 - val_accuracy: 0.4796 - lr: 1.0000e-05
# Epoch 167/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5202 - accuracy: 0.5872 - val_loss: 2.1629 - val_accuracy: 0.4724 - lr: 1.0000e-05
# Epoch 168/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5413 - accuracy: 0.5763 - val_loss: 2.1385 - val_accuracy: 0.4772 - lr: 1.0000e-05
# Epoch 169/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5158 - accuracy: 0.5834 - val_loss: 2.1504 - val_accuracy: 0.4764 - lr: 1.0000e-05
# Epoch 170/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5297 - accuracy: 0.5862 - val_loss: 2.0714 - val_accuracy: 0.4888 - lr: 1.0000e-05
# Epoch 171/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5288 - accuracy: 0.5845 - val_loss: 2.1226 - val_accuracy: 0.4868 - lr: 1.0000e-05
# Epoch 172/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5256 - accuracy: 0.5821 - val_loss: 2.1641 - val_accuracy: 0.4694 - lr: 1.0000e-05
# Epoch 173/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5280 - accuracy: 0.5830 - val_loss: 2.1389 - val_accuracy: 0.4774 - lr: 1.0000e-05
# Epoch 174/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5209 - accuracy: 0.5829 - val_loss: 2.1687 - val_accuracy: 0.4780 - lr: 1.0000e-05
# Epoch 175/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5194 - accuracy: 0.5839 - val_loss: 2.1415 - val_accuracy: 0.4824 - lr: 1.0000e-05
# Epoch 176/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5155 - accuracy: 0.5850 - val_loss: 2.0883 - val_accuracy: 0.4830 - lr: 1.0000e-05
# Epoch 177/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5073 - accuracy: 0.5890 - val_loss: 2.1067 - val_accuracy: 0.4782 - lr: 1.0000e-05
# Epoch 178/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5050 - accuracy: 0.5919 - val_loss: 2.1315 - val_accuracy: 0.4754 - lr: 1.0000e-05
# Epoch 179/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5198 - accuracy: 0.5867 - val_loss: 2.1764 - val_accuracy: 0.4702 - lr: 1.0000e-05
# Epoch 180/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5169 - accuracy: 0.5852 - val_loss: 2.1440 - val_accuracy: 0.4816 - lr: 1.0000e-05
# Epoch 181/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5031 - accuracy: 0.5923 - val_loss: 2.1322 - val_accuracy: 0.4794 - lr: 1.0000e-05
# Epoch 182/256
# 625/625 [==============================] - 70s 113ms/step - loss: 1.5196 - accuracy: 0.5815 - val_loss: 2.0983 - val_accuracy: 0.4820 - lr: 1.0000e-05
# Epoch 183/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5123 - accuracy: 0.5869 - val_loss: 2.1429 - val_accuracy: 0.4742 - lr: 1.0000e-05
# Epoch 184/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5428 - accuracy: 0.5782 - val_loss: 2.1142 - val_accuracy: 0.4792 - lr: 1.0000e-05
# Epoch 185/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5227 - accuracy: 0.5875 - val_loss: 2.1068 - val_accuracy: 0.4830 - lr: 1.0000e-05
# Epoch 186/256
# 625/625 [==============================] - 76s 121ms/step - loss: 1.5073 - accuracy: 0.5886 - val_loss: 2.0803 - val_accuracy: 0.4888 - lr: 1.0000e-05
# Epoch 187/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5103 - accuracy: 0.5882 - val_loss: 2.1671 - val_accuracy: 0.4734 - lr: 1.0000e-05
# Epoch 188/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5118 - accuracy: 0.5863 - val_loss: 2.0984 - val_accuracy: 0.4832 - lr: 1.0000e-05
# Epoch 189/256
# 625/625 [==============================] - 71s 113ms/step - loss: 1.5130 - accuracy: 0.5844 - val_loss: 2.1148 - val_accuracy: 0.4788 - lr: 1.0000e-05
# Epoch 190/256
# 625/625 [==============================] - 73s 117ms/step - loss: 1.5053 - accuracy: 0.5873 - val_loss: 2.1118 - val_accuracy: 0.4812 - lr: 1.0000e-05
# Epoch 191/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5231 - accuracy: 0.5857 - val_loss: 2.1285 - val_accuracy: 0.4746 - lr: 1.0000e-05
# Epoch 192/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5066 - accuracy: 0.5859 - val_loss: 2.1174 - val_accuracy: 0.4878 - lr: 1.0000e-05
# Epoch 193/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5097 - accuracy: 0.5879 - val_loss: 2.1191 - val_accuracy: 0.4750 - lr: 1.0000e-05
# Epoch 194/256
# 625/625 [==============================] - 73s 117ms/step - loss: 1.5078 - accuracy: 0.5888 - val_loss: 2.0694 - val_accuracy: 0.4836 - lr: 1.0000e-05
# Epoch 195/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5240 - accuracy: 0.5813 - val_loss: 2.1017 - val_accuracy: 0.4826 - lr: 1.0000e-05
# Epoch 196/256
# 625/625 [==============================] - 77s 123ms/step - loss: 1.5021 - accuracy: 0.5893 - val_loss: 2.1060 - val_accuracy: 0.4866 - lr: 1.0000e-05
# Epoch 197/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5130 - accuracy: 0.5868 - val_loss: 2.1277 - val_accuracy: 0.4802 - lr: 1.0000e-05
# Epoch 198/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5107 - accuracy: 0.5864 - val_loss: 2.0860 - val_accuracy: 0.4892 - lr: 1.0000e-05
# Epoch 199/256
# 625/625 [==============================] - 72s 114ms/step - loss: 1.5246 - accuracy: 0.5821 - val_loss: 2.1140 - val_accuracy: 0.4848 - lr: 1.0000e-05
# Epoch 200/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5162 - accuracy: 0.5862 - val_loss: 2.1098 - val_accuracy: 0.4836 - lr: 1.0000e-05
# Epoch 201/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4997 - accuracy: 0.5878 - val_loss: 2.1210 - val_accuracy: 0.4872 - lr: 1.0000e-05
# Epoch 202/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5025 - accuracy: 0.5850 - val_loss: 2.1480 - val_accuracy: 0.4708 - lr: 1.0000e-05
# Epoch 203/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5148 - accuracy: 0.5871 - val_loss: 2.1392 - val_accuracy: 0.4826 - lr: 1.0000e-05
# Epoch 204/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5039 - accuracy: 0.5884 - val_loss: 2.1544 - val_accuracy: 0.4758 - lr: 1.0000e-05
# Epoch 205/256
# 625/625 [==============================] - 77s 122ms/step - loss: 1.5031 - accuracy: 0.5903 - val_loss: 2.1018 - val_accuracy: 0.4796 - lr: 1.0000e-05
# Epoch 206/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5075 - accuracy: 0.5887 - val_loss: 2.1358 - val_accuracy: 0.4692 - lr: 1.0000e-05
# Epoch 207/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5174 - accuracy: 0.5854 - val_loss: 2.0780 - val_accuracy: 0.4916 - lr: 1.0000e-05
# Epoch 208/256
# 625/625 [==============================] - 77s 123ms/step - loss: 1.5241 - accuracy: 0.5840 - val_loss: 2.1397 - val_accuracy: 0.4822 - lr: 1.0000e-05
# Epoch 209/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5180 - accuracy: 0.5853 - val_loss: 2.1028 - val_accuracy: 0.4838 - lr: 1.0000e-05
# Epoch 210/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4986 - accuracy: 0.5909 - val_loss: 2.1101 - val_accuracy: 0.4854 - lr: 1.0000e-05
# Epoch 211/256
# 625/625 [==============================] - 77s 123ms/step - loss: 1.4978 - accuracy: 0.5920 - val_loss: 2.1486 - val_accuracy: 0.4830 - lr: 1.0000e-05
# Epoch 212/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5009 - accuracy: 0.5899 - val_loss: 2.1489 - val_accuracy: 0.4784 - lr: 1.0000e-05
# Epoch 213/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4879 - accuracy: 0.5983 - val_loss: 2.1274 - val_accuracy: 0.4814 - lr: 1.0000e-05
# Epoch 214/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5068 - accuracy: 0.5852 - val_loss: 2.1476 - val_accuracy: 0.4780 - lr: 1.0000e-05
# Epoch 215/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5067 - accuracy: 0.5875 - val_loss: 2.1546 - val_accuracy: 0.4780 - lr: 1.0000e-05
# Epoch 216/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4991 - accuracy: 0.5852 - val_loss: 2.1133 - val_accuracy: 0.4832 - lr: 1.0000e-05
# Epoch 217/256
# 625/625 [==============================] - 77s 123ms/step - loss: 1.4884 - accuracy: 0.5949 - val_loss: 2.1514 - val_accuracy: 0.4862 - lr: 1.0000e-05
# Epoch 218/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5051 - accuracy: 0.5886 - val_loss: 2.1361 - val_accuracy: 0.4846 - lr: 1.0000e-05
# Epoch 219/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4908 - accuracy: 0.5924 - val_loss: 2.1754 - val_accuracy: 0.4756 - lr: 1.0000e-05
# Epoch 220/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4882 - accuracy: 0.5925 - val_loss: 2.1217 - val_accuracy: 0.4824 - lr: 1.0000e-05
# Epoch 221/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5147 - accuracy: 0.5867 - val_loss: 2.1253 - val_accuracy: 0.4800 - lr: 1.0000e-05
# Epoch 222/256
# 625/625 [==============================] - 77s 123ms/step - loss: 1.4930 - accuracy: 0.5903 - val_loss: 2.0889 - val_accuracy: 0.4938 - lr: 1.0000e-05
# Epoch 223/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5213 - accuracy: 0.5856 - val_loss: 2.1316 - val_accuracy: 0.4782 - lr: 1.0000e-05
# Epoch 224/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4803 - accuracy: 0.5975 - val_loss: 2.1354 - val_accuracy: 0.4770 - lr: 1.0000e-05
# Epoch 225/256
# 625/625 [==============================] - 77s 123ms/step - loss: 1.4904 - accuracy: 0.5885 - val_loss: 2.1427 - val_accuracy: 0.4748 - lr: 1.0000e-05
# Epoch 226/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.5016 - accuracy: 0.5881 - val_loss: 2.1408 - val_accuracy: 0.4782 - lr: 1.0000e-05
# Epoch 227/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5204 - accuracy: 0.5824 - val_loss: 2.0773 - val_accuracy: 0.4904 - lr: 1.0000e-05
# Epoch 228/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5052 - accuracy: 0.5912 - val_loss: 2.0995 - val_accuracy: 0.4800 - lr: 1.0000e-05
# Epoch 229/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4965 - accuracy: 0.5912 - val_loss: 2.1181 - val_accuracy: 0.4830 - lr: 1.0000e-05
# Epoch 230/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5082 - accuracy: 0.5897 - val_loss: 2.1233 - val_accuracy: 0.4754 - lr: 1.0000e-05
# Epoch 231/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4956 - accuracy: 0.5922 - val_loss: 2.1106 - val_accuracy: 0.4864 - lr: 1.0000e-05
# Epoch 232/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4955 - accuracy: 0.5899 - val_loss: 2.0829 - val_accuracy: 0.4848 - lr: 1.0000e-05
# Epoch 233/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5008 - accuracy: 0.5899 - val_loss: 2.0834 - val_accuracy: 0.4860 - lr: 1.0000e-05
# Epoch 234/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4970 - accuracy: 0.5881 - val_loss: 2.1054 - val_accuracy: 0.4796 - lr: 1.0000e-05
# Epoch 235/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4943 - accuracy: 0.5908 - val_loss: 2.0890 - val_accuracy: 0.4940 - lr: 1.0000e-05
# Epoch 236/256
# 625/625 [==============================] - 72s 114ms/step - loss: 1.4868 - accuracy: 0.5915 - val_loss: 2.1282 - val_accuracy: 0.4864 - lr: 1.0000e-05
# Epoch 237/256
# 625/625 [==============================] - 72s 116ms/step - loss: 1.4924 - accuracy: 0.5883 - val_loss: 2.0640 - val_accuracy: 0.4932 - lr: 1.0000e-05
# Epoch 238/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4709 - accuracy: 0.5932 - val_loss: 2.1293 - val_accuracy: 0.4828 - lr: 1.0000e-05
# Epoch 239/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5162 - accuracy: 0.5840 - val_loss: 2.1033 - val_accuracy: 0.4828 - lr: 1.0000e-05
# Epoch 240/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4875 - accuracy: 0.5958 - val_loss: 2.0416 - val_accuracy: 0.4942 - lr: 1.0000e-05
# Epoch 241/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5035 - accuracy: 0.5904 - val_loss: 2.1691 - val_accuracy: 0.4685 - lr: 1.0000e-05
# Epoch 242/256
# 625/625 [==============================] - 72s 114ms/step - loss: 1.4867 - accuracy: 0.5975 - val_loss: 2.1626 - val_accuracy: 0.4796 - lr: 1.0000e-05
# Epoch 243/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5017 - accuracy: 0.5915 - val_loss: 2.0981 - val_accuracy: 0.4864 - lr: 1.0000e-05
# Epoch 244/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4907 - accuracy: 0.5892 - val_loss: 2.0731 - val_accuracy: 0.4912 - lr: 1.0000e-05
# Epoch 245/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4994 - accuracy: 0.5901 - val_loss: 2.1363 - val_accuracy: 0.4748 - lr: 1.0000e-05
# Epoch 246/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4730 - accuracy: 0.5976 - val_loss: 2.0716 - val_accuracy: 0.4978 - lr: 1.0000e-05
# Epoch 247/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4947 - accuracy: 0.5909 - val_loss: 2.1074 - val_accuracy: 0.4848 - lr: 1.0000e-05
# Epoch 248/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4979 - accuracy: 0.5899 - val_loss: 2.0944 - val_accuracy: 0.4882 - lr: 1.0000e-05
# Epoch 249/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4971 - accuracy: 0.5903 - val_loss: 2.1339 - val_accuracy: 0.4750 - lr: 1.0000e-05
# Epoch 250/256
# 625/625 [==============================] - 72s 114ms/step - loss: 1.4884 - accuracy: 0.5950 - val_loss: 2.1384 - val_accuracy: 0.4756 - lr: 1.0000e-05
# Epoch 251/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4896 - accuracy: 0.5975 - val_loss: 2.1405 - val_accuracy: 0.4758 - lr: 1.0000e-05
# Epoch 252/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4866 - accuracy: 0.5915 - val_loss: 2.1527 - val_accuracy: 0.4818 - lr: 1.0000e-05
# Epoch 253/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.5013 - accuracy: 0.5900 - val_loss: 2.1352 - val_accuracy: 0.4778 - lr: 1.0000e-05
# Epoch 254/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4874 - accuracy: 0.5934 - val_loss: 2.1312 - val_accuracy: 0.4710 - lr: 1.0000e-05
# Epoch 255/256
# 625/625 [==============================] - 71s 114ms/step - loss: 1.4763 - accuracy: 0.5946 - val_loss: 2.1138 - val_accuracy: 0.4860 - lr: 1.0000e-05
# Epoch 256/256
# 625/625 [==============================] - 72s 115ms/step - loss: 1.4979 - accuracy: 0.5890 - val_loss: 2.1203 - val_accuracy: 0.4836 - lr: 1.0000e-05

# %%
print("\n Time to train CIFAR-100 with batch size of 64: ", (toc - tic)/60, "mins")
# Out:
#  Time to train CIFAR-100 with batch size of 64:  325.31045182148614 mins

# %%
model_cifar_100.save('model_cifar_100_batch_size_64.h5')

# %%
plt.plot(history_cifar_100.history['accuracy'], label = 'Training')
plt.plot(history_cifar_100.history['val_accuracy'], label = 'Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'upper left')
plt.title("Accuracy vs Epochs")

print("\n Final training accuracy for CIFAR-100 with batch size of 64: ", history_cifar_100.history['accuracy'][-1]*100, "%")
print("\n Final validation accuracy for CIFAR-100 with batch size of 64: ", history_cifar_100.history['val_accuracy'][-1]*100, "%")
# Out:
#  Final training accuracy for CIFAR-100 with batch size of 64:  58.89999866485596 %
#
#  Final validation accuracy for CIFAR-100 with batch size of 64:  48.357370495796204 %

# %%
plt.plot(history_cifar_100.history['loss'], label = 'Training')
plt.plot(history_cifar_100.history['val_loss'], label = 'Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = 'upper left')
plt.title("Loss vs Epochs")

print("\n Final training loss for CIFAR-100 with batch size of 64: ", history_cifar_100.history['loss'][-1])
print("\n Final validation loss for CIFAR-100 with batch size of 64: ", history_cifar_100.history['val_loss'][-1])
# Out:
#  Final training loss for CIFAR-100 with batch size of 64:  1.497881293296814
#
#  Final validation loss for CIFAR-100 with batch size of 64:  2.1202664375305176
